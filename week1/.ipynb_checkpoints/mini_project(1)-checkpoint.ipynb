# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

df = pd.read_csv('Titanic-Dataset.csv')

# Assignment 1: Summarize basic statistics
print("--- DATASET INFO ---")
df.info()

print("\n--- STATISTICAL SUMMARY ---")
print(df.describe())
# Out:
# --- DATASET INFO ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# --- STATISTICAL SUMMARY ---
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
# Handle missing data using median imputation for numerical data
df['Age'] = df['Age'].fillna(df['Age'].median())

# For categorical column 'embarked' ,'cabin', fill missing values with the most frequent value (mode)

df["Cabin"]=df['Cabin'].fillna(df['Cabin'].mode()[0])

df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

print("\nMissing values after cleaning:\n", df.isnull().sum())
# Out:
# Missing values after cleaning:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# 1. LabelEncoder for 'sex' column (Converts to 0 or 1)
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# 2. OneHotEncoder for 'embarked' column (Creates binary columns)
# We use pandas get_dummies as it handles OneHotEncoding instantly in data science
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)
df = pd.get_dummies(df, columns=['Pclass'], drop_first=True)
df.drop(columns=["PassengerId","Name","Ticket","Cabin",],axis=1, inplace=True )


print("--- ENCODED DATA PREVIEW ---")
print(df[['Sex', 'Age']].head())
# Out:
# --- ENCODED DATA PREVIEW ---
#    Sex   Age
# 0    1  22.0
# 1    0  38.0
# 2    0  26.0
# 3    0  35.0
# 4    1  35.0

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Age'], kde=True, color='BLUE')
plt.title('Titanic Passengers Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show() 

# Save the final cleaned dataset as a new CSV file
df.to_csv('Cleaned_Titanic_Dataset.csv', index=False)
print("Project Complete! 'Cleaned_Titanic_Dataset.csv' has been generated in your workspace.")
# Out:
# Project Complete! 'Cleaned_Titanic_Dataset.csv' has been generated in your workspace.

# %%
df.head()
# Out:
#    Survived  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S  \
# 0         0    1  22.0      1      0   7.2500       False        True
# 1         1    0  38.0      1      0  71.2833       False       False
# 2         1    0  26.0      0      0   7.9250       False        True
# 3         1    0  35.0      1      0  53.1000       False        True
# 4         0    1  35.0      0      0   8.0500       False        True
#
#    Pclass_2  Pclass_3
# 0     False      True
# 1     False     False
# 2     False      True
# 3     False     False
# 4     False      True
